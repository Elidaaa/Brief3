# %%
import pandas as pd

# %%
#question1

df_google_ap_1 = pd.read_csv('googleplaystore_1.csv', sep = ";")

# %%
df_google_ap_1
# Out:
#                                                    App        Category Rating  \
# 0       Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN    4.1
# 1                                  Coloring book moana  ART_AND_DESIGN    3.9
# 2                                Sketch - Draw & Paint  ART_AND_DESIGN    4.5
# 3                Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN    4.3
# 4                           Paper flowers instructions  ART_AND_DESIGN    4.4
# ..                                                 ...             ...    ...
# 495                          BBWCupid - BBW Dating App          DATING    3.5
# 496                          ChatVideo Meet new people          DATING    4.2
# 497  Black White Interracial Dating - Interracial M...          DATING    4.1
# 498             FlirtChat - ♥Free Dating/Flirting App♥          DATING    4.3
# 499                                     OkCupid Dating          DATING    4.1
#
# ...

# %%
#question2

df_google_ap_1['Installs'].value_counts()
# Out:
# 1,000,000+            102
# 100,000+               92
# 10,000,000+            70
# 5,000,000+             52
# 500,000+               46
# 10,000+                33
# 100,000,000+           28
# 50,000+                26
# 1,000,000,000+         14
# 500,000,000+           12
# 50,000,000+            10
# 5,000+                  6
# Varies with device      3
# 1,000+                  2
# 100+                    2
# 3.6M                    1
# 50+                     1
# Name: Installs, dtype: int64

# %%
df_google_ap_1.loc[df_google_ap_1['Installs'] == "1,000,000,000+"]
# Out:
#                                           App             Category Rating  \
# 139                         Google Play Books  BOOKS_AND_REFERENCE    3.9
# 313  Messenger – Text and Video Chat for Free        COMMUNICATION    4.0
# 314                        WhatsApp Messenger        COMMUNICATION    4.4
# 316              Google Chrome: Fast & Secure        COMMUNICATION    4.3
# 318                                     Gmail        COMMUNICATION    4.3
# 319                                  Hangouts        COMMUNICATION    4.0
# 359                        WhatsApp Messenger        COMMUNICATION    4.4
# 360  Messenger – Text and Video Chat for Free        COMMUNICATION    4.0
# 364                                  Hangouts        COMMUNICATION    4.0
# 368             Skype - free IM & video calls        COMMUNICATION    4.1
# 386              Google Chrome: Fast & Secure        COMMUNICATION    4.3
# 424                                     Gmail        COMMUNICATION    4.3
# ...

# %%
Table_1 = df_google_ap_1.loc[df_google_ap_1['Installs'] == "1,000,000,000+"]

# %%
Table_1.drop(['Rating', 'Reviews', 'Size', 'Type', 'Price', 'Content Rating', 'Last Updated', 'Current Ver', 'Android Ver'], axis=1)
# Out:
#                                           App             Category  \
# 139                         Google Play Books  BOOKS_AND_REFERENCE
# 313  Messenger – Text and Video Chat for Free        COMMUNICATION
# 314                        WhatsApp Messenger        COMMUNICATION
# 316              Google Chrome: Fast & Secure        COMMUNICATION
# 318                                     Gmail        COMMUNICATION
# 319                                  Hangouts        COMMUNICATION
# 359                        WhatsApp Messenger        COMMUNICATION
# 360  Messenger – Text and Video Chat for Free        COMMUNICATION
# 364                                  Hangouts        COMMUNICATION
# 368             Skype - free IM & video calls        COMMUNICATION
# 386              Google Chrome: Fast & Secure        COMMUNICATION
# 424                                     Gmail        COMMUNICATION
# 436                                  Hangouts        COMMUNICATION
# ...

# %%
#Question3 : le plus grand nombre de Reviews

df_google_ap_1['Reviews'].max()
# Out:
# 69119316.0

# %%
#Question4 : nom et note de l'application concernée

df_google_ap_1['Reviews'].idxmax()
# Out:
# 314

# %%
df_google_ap_1.iloc[314,:]
# Out:
# App               WhatsApp Messenger
# Category               COMMUNICATION
# Rating                           4.4
# Reviews                   69119316.0
# Size              Varies with device
# Installs              1,000,000,000+
# Type                            Free
# Price                              0
# Content Rating              Everyone
# Genres                 Communication
# Last Updated          August 3, 2018
# Current Ver       Varies with device
# Android Ver       Varies with device
# Name: 314, dtype: object

# %%
df_google_ap_1.loc[314, ['App', 'Rating', 'Reviews']]
# Out:
# App        WhatsApp Messenger
# Rating                    4.4
# Reviews            69119316.0
# Name: 314, dtype: object

# %%
#Question4 : afficher les colonnes 2,5,6 et les lignes 3 à 16 du Dataframe

df_google_ap_1.iloc[3:16, [2, 5, 6]]
# Out:
#    Rating     Installs  Type
# 3     4.3     100,000+  Free
# 4     4.4      50,000+  Free
# 5     3.8      50,000+  Free
# 6     4.1   1,000,000+  Free
# 7     4.4   1,000,000+  Free
# 8     4.7      10,000+  Free
# 9     4.4   1,000,000+  Free
# 10    4.4   1,000,000+  Free
# 11    4.2  10,000,000+  Free
# 12    4.6     100,000+  Free
# 13    4.4     100,000+  Free
# 14    3.2       5,000+  Free
# 15    4.7     500,000+  Free

# %%
#Question5 : combien y-a-t-il d'applications ouvertes aux personnes de tous âges ?

df_google_ap_1['Content Rating'].value_counts()
# Out:
# Everyone           391
# Mature 17+          61
# Teen                35
# Everyone 10+         8
# 0                    4
# Adults only 18+      1
# Name: Content Rating, dtype: int64

# %%
# Il y a 396 applications ouvertes aux personnes de tous âges.

# %%
#Question6 : dans quelle catégories y-a-t-il le plus d'applications ?

df_google_ap_1['Category'].value_counts()
# Out:
# COMMUNICATION                               132
# BUSINESS                                    106
# DATING                                       52
# ART_AND_DESIGN                               47
# BOOKS_AND_REFERENCE                          47
# AUTO_AND_VEHICLES                            43
# BEAUTY                                       35
# COMICS                                       34
#  find information about Swedish vehicles      1
#  Private & Adblock🐬                           1
#  SMS spam blocking & Dialer                   1
#  Gmail and Outlook Mail                       1
# Name: Category, dtype: int64

# %%
#Il y a plus d'applications dans la catégorie COMMUNICATION.

# %%
#Question7 : quelle est l'application vendue la plus chère ?

df_google_ap_1['Price'].value_counts()
# Out:
# 0        487
# Free       4
# $4.99      4
# $3.99      2
# $6.99      1
# $1.49      1
# $7.99      1
# Name: Price, dtype: int64

# %%
df_google_ap_1.loc[df_google_ap_1['Price'] == "$7.99"]
# Out:
#                                                    App Category Rating  \
# 451  AMBW Dating App: Asian Men Black Women Interra...   DATING    3.5
#
#      Reviews Size Installs  Type  Price Content Rating  Genres  \
# 451      2.0  17M     100+  Paid  $7.99     Mature 17+  Dating
#
#          Last Updated Current Ver Android Ver
# 451  January 21, 2017       1.0.1  4.0 and up

# %%
df_google_ap_1.loc[451, 'App']
# Out:
# 'AMBW Dating App: Asian Men Black Women Interracial'

# %%
#L'application vendue la plus chère est la 'AMBW Dating App: Asian Men Black Women Interracial'.
